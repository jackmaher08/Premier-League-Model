# %%
import pandas as pd

# %%
#Scrape the results dataom FBRef - using the 23/24 season

df = pd.read_html('https://fbref.com/en/comps/9/2023-2024/schedule/2023-2024-Premier-League-Scores-and-Fixtures', # allows us to read tables from html - paste in the link and css selectors
                  attrs={"id":"sched_2023-2024_9_1"})[0] # add the [0] to return the first item in the list - looks better

# %%
df.head()
# Out:
#     Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0  1.0  Fri  2023-08-11  20:00        Burnley  0.3   0–3   1.9
# 1  1.0  Sat  2023-08-12  12:30        Arsenal  0.8   2–1   1.2
# 2  1.0  Sat  2023-08-12  15:00        Everton  2.7   0–1   1.5
# 3  1.0  Sat  2023-08-12  15:00  Sheffield Utd  0.5   0–1   1.9
# 4  1.0  Sat  2023-08-12  15:00       Brighton  4.0   4–1   1.5
#
#               Away  Attendance                                   Venue  \
# 0  Manchester City     21572.0                               Turf Moor
# 1  Nott'ham Forest     59984.0                        Emirates Stadium
# 2           Fulham     39940.0                           Goodison Park
# 3   Crystal Palace     31194.0                            Bramall Lane
# 4       Luton Town     31872.0  The American Express Community Stadium
#
#           Referee  Match Report  Notes
# 0    Craig Pawson  Match Report    NaN
# 1  Michael Oliver  Match Report    NaN
# 2  Stuart Attwell  Match Report    NaN
# 3     John Brooks  Match Report    NaN
# 4     David Coote  Match Report    NaN

# %%
# remove the 'nan' row from the above data - Fbref uses a 'nan' row as a separator, so we'll remove those rows
df = df.dropna(subset=['Home'])

# %%
df.head()
# Out:
#     Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0  1.0  Fri  2023-08-11  20:00        Burnley  0.3   0–3   1.9
# 1  1.0  Sat  2023-08-12  12:30        Arsenal  0.8   2–1   1.2
# 2  1.0  Sat  2023-08-12  15:00        Everton  2.7   0–1   1.5
# 3  1.0  Sat  2023-08-12  15:00  Sheffield Utd  0.5   0–1   1.9
# 4  1.0  Sat  2023-08-12  15:00       Brighton  4.0   4–1   1.5
#
#               Away  Attendance                                   Venue  \
# 0  Manchester City     21572.0                               Turf Moor
# 1  Nott'ham Forest     59984.0                        Emirates Stadium
# 2           Fulham     39940.0                           Goodison Park
# 3   Crystal Palace     31194.0                            Bramall Lane
# 4       Luton Town     31872.0  The American Express Community Stadium
#
#           Referee  Match Report  Notes  home_goals  away_goals    result
# 0    Craig Pawson  Match Report    NaN         0.0         3.0  away_win
# 1  Michael Oliver  Match Report    NaN         2.0         1.0  home_win
# 2  Stuart Attwell  Match Report    NaN         0.0         1.0  away_win
# 3     John Brooks  Match Report    NaN         0.0         1.0  away_win
# 4     David Coote  Match Report    NaN         4.0         1.0  home_win

# %%
# Extract unique team names from column 'Home'
team_names = df['Home'].unique()

# Display the unique team names
print("Teams:")
for team in team_names:
    print(team)
# Out:
# Teams:
# Burnley
# Arsenal
# Everton
# Sheffield Utd
# Brighton
# Bournemouth
# Newcastle Utd
# Brentford
# Chelsea
# Manchester Utd
# Nott'ham Forest
# Fulham
# Liverpool
# Wolves
# Tottenham
# Manchester City
# Aston Villa
# West Ham
# Crystal Palace
# Luton Town

# %%
# Split the 'Score' column into 'Home Goals' and 'Away Goals' columns
df[['home_goals', 'away_goals']] = df['Score'].str.split('–', expand=True).astype(float)

# %%
# Determine the match outcome from the home and away goals

def get_outcome(row):
    if row['home_goals'] > row['away_goals']:
        return 'home_win'
    elif row['home_goals'] < row['away_goals']:
        return 'away_win'
    else:
        return 'draw'

# Create an outcome column following the above to record match winner
df['result'] = df.apply(get_outcome, axis=1)

# %%
# this tells us the columns we have in our DF

df.columns
# Out:
# Index(['Wk', 'Day', 'Date', 'Time', 'Home', 'xG', 'Score', 'xG.1', 'Away',
#        'Attendance', 'Venue', 'Referee', 'Match Report', 'Notes', 'home_goals',
#        'away_goals', 'result'],
#       dtype='object')

# %%
# Calc number of fixtures
total_games = len(df)

# Calc home wins, away wins, and draws
home_wins = len(df[df['result'] == 'home_win'])
away_wins = len(df[df['result'] == 'away_win'])
draws = len(df[df['result'] == 'draw'])

# Calc win rates
home_win_rate = home_wins / total_games
away_win_rate = away_wins / total_games
draw_rate = draws / total_games

# Calc home-field advantage
home_field_advantage = home_win_rate - away_win_rate

print("Home Win Rate:", home_win_rate)
print("Away Win Rate:", away_win_rate)
print("Draw Rate:", draw_rate)
print("Home-Field Advantage:", home_field_advantage)
# Out:
# Home Win Rate: 0.41371158392434987
# Away Win Rate: 0.2907801418439716
# Draw Rate: 0.29550827423167847
# Home-Field Advantage: 0.12293144208037826

# %%
# Create Dict to store data for each team
team_data = {}

# Loop through each team
for team in team_names:
    # Filter rows for the teams as Home Team
    home_team_rows = df[df['Home'] == team]

    # Calculate average goals for and against as Home Team
    avg_home_goals_for = home_team_rows['home_goals'].mean()
    avg_away_goals_against = home_team_rows['away_goals'].mean()

    # Filter rows for the specific team as Away Team
    away_team_rows = df[df['Away'] == team]

    # Calculate average goals for and against as Away Team
    avg_away_goals_for = away_team_rows['away_goals'].mean()
    avg_home_goals_against = away_team_rows['home_goals'].mean()

    # Calculate average goals for and against for each team
    OFF_rating = (avg_home_goals_for + avg_away_goals_for) / 2
    DEF_rating = (avg_home_goals_against + avg_away_goals_against) / 2

    # Store calculated data in the dictionary
    team_data[team] = {
        'Home Goals For': avg_home_goals_for,
        'Away Goals For': avg_away_goals_for,
        'Home Goals Against': avg_home_goals_against,
        'Away Goals Against': avg_away_goals_against,
        'OFF Rating': OFF_rating,
        'DEF Rating': DEF_rating
    }

# Display calculated data for each team
print("Team Data: AVG Goals & Ratings")
print()
# loop through each team to assign the team data
for team, data in team_data.items():
    print(f"{team}:")
    print(f"  Home Goals For: {data['Home Goals For']:.5f}")
    print(f"  Home Goals Against: {data['Home Goals Against']:.5f}")
    print(f"  Away Goals For: {data['Away Goals For']:.5f}")
    print(f"  Away Goals Against: {data['Away Goals Against']:.5f}")
    print(f"  OFF Rating: {data['OFF Rating']:.2f}")
    print(f"  DEF Rating: {data['DEF Rating']:.2f}")
    print()
# Out:
# Team Data: AVG Goals & Ratings
#
# Burnley:
#   Home Goals For: 1.00000
#   Home Goals Against: 1.84211
#   Away Goals For: 1.15789
#   Away Goals Against: 2.26316
#   OFF Rating: 1.08
#   DEF Rating: 2.05
#
# Arsenal:
#   Home Goals For: 2.52632
#   Home Goals Against: 0.68421
#   Away Goals For: 2.26316
#   Away Goals Against: 0.84211
#   OFF Rating: 2.39
#   DEF Rating: 0.76
#
# Everton:
#   Home Goals For: 1.15789
#   Home Goals Against: 1.73684
#   Away Goals For: 0.94737
#   Away Goals Against: 0.94737
#   OFF Rating: 1.05
#   DEF Rating: 1.34
#
# Sheffield Utd:
#   Home Goals For: 1.00000
#   Home Goals Against: 2.47368
#   Away Goals For: 0.84211
#   Away Goals Against: 3.00000
#   OFF Rating: 0.92
#   DEF Rating: 2.74
#
# Brighton:
#   Home Goals For: 1.57895
#   Home Goals Against: 1.84211
#   Away Goals For: 1.31579
#   Away Goals Against: 1.42105
#   OFF Rating: 1.45
#   DEF Rating: 1.63
#
# Bournemouth:
#   Home Goals For: 1.42105
#   Home Goals Against: 2.05263
#   Away Goals For: 1.42105
#   Away Goals Against: 1.47368
#   OFF Rating: 1.42
#   DEF Rating: 1.76
#
# Newcastle Utd:
#   Home Goals For: 2.57895
#   Home Goals Against: 2.10526
#   Away Goals For: 1.89474
#   Away Goals Against: 1.15789
#   OFF Rating: 2.24
#   DEF Rating: 1.63
#
# Brentford:
#   Home Goals For: 1.52632
#   Home Goals Against: 1.63158
#   Away Goals For: 1.42105
#   Away Goals Against: 1.78947
#   OFF Rating: 1.47
#   DEF Rating: 1.71
#
# Chelsea:
#   Home Goals For: 2.31579
#   Home Goals Against: 1.94737
#   Away Goals For: 1.73684
#   Away Goals Against: 1.36842
#   OFF Rating: 2.03
#   DEF Rating: 1.66
#
# Manchester Utd:
#   Home Goals For: 1.63158
#   Home Goals Against: 1.57895
#   Away Goals For: 1.36842
#   Away Goals Against: 1.47368
#   OFF Rating: 1.50
#   DEF Rating: 1.53
#
# nan:
#   Home Goals For: nan
#   Home Goals Against: nan
#   Away Goals For: nan
#   Away Goals Against: nan
#   OFF Rating: nan
#   DEF Rating: nan
#
# Nott'ham Forest:
#   Home Goals For: 1.42105
#   Home Goals Against: 1.94737
#   Away Goals For: 1.15789
#   Away Goals Against: 1.57895
#   OFF Rating: 1.29
#   DEF Rating: 1.76
#
# Fulham:
#   Home Goals For: 1.63158
#   Home Goals Against: 1.94737
#   Away Goals For: 1.26316
#   Away Goals Against: 1.26316
#   OFF Rating: 1.45
#   DEF Rating: 1.61
#
# Liverpool:
#   Home Goals For: 2.57895
#   Home Goals Against: 1.26316
#   Away Goals For: 1.94737
#   Away Goals Against: 0.89474
#   OFF Rating: 2.26
#   DEF Rating: 1.08
#
# Wolves:
#   Home Goals For: 1.36842
#   Home Goals Against: 1.84211
#   Away Goals For: 1.26316
#   Away Goals Against: 1.57895
#   OFF Rating: 1.32
#   DEF Rating: 1.71
#
# Tottenham:
#   Home Goals For: 2.00000
#   Home Goals Against: 1.78947
#   Away Goals For: 1.89474
#   Away Goals Against: 1.42105
#   OFF Rating: 1.95
#   DEF Rating: 1.61
#
# Manchester City:
#   Home Goals For: 2.68421
#   Home Goals Against: 0.94737
#   Away Goals For: 2.36842
#   Away Goals Against: 0.84211
#   OFF Rating: 2.53
#   DEF Rating: 0.89
#
# Aston Villa:
#   Home Goals For: 2.52632
#   Home Goals Against: 1.73684
#   Away Goals For: 1.47368
#   Away Goals Against: 1.47368
#   OFF Rating: 2.00
#   DEF Rating: 1.61
#
# West Ham:
#   Home Goals For: 1.63158
#   Home Goals Against: 2.42105
#   Away Goals For: 1.52632
#   Away Goals Against: 1.47368
#   OFF Rating: 1.58
#   DEF Rating: 1.95
#
# Crystal Palace:
#   Home Goals For: 1.94737
#   Home Goals Against: 1.68421
#   Away Goals For: 1.05263
#   Away Goals Against: 1.36842
#   OFF Rating: 1.50
#   DEF Rating: 1.53
#
# Luton Town:
#   Home Goals For: 1.47368
#   Home Goals Against: 2.52632
#   Away Goals For: 1.26316
#   Away Goals Against: 1.94737
#   OFF Rating: 1.37
#   DEF Rating: 2.24

# %%
# Target just OFF & DEF for each team from the above

for team, stats in team_data.items():
    off_rating = stats.get('OFF Rating')
    def_rating = stats.get('DEF Rating')
    
    print(f"Team: {team}")
    print(f"OFF Rating: {off_rating}")
    print(f"DEF Rating: {def_rating}")
    print("-" * 30)
# Out:
# Team: Burnley
# OFF Rating: 1.0789473684210527
# DEF Rating: 2.052631578947368
# ------------------------------
# Team: Arsenal
# OFF Rating: 2.394736842105263
# DEF Rating: 0.763157894736842
# ------------------------------
# Team: Everton
# OFF Rating: 1.0526315789473684
# DEF Rating: 1.3421052631578947
# ------------------------------
# Team: Sheffield Utd
# OFF Rating: 0.9210526315789473
# DEF Rating: 2.736842105263158
# ------------------------------
# Team: Brighton
# OFF Rating: 1.4473684210526316
# DEF Rating: 1.631578947368421
# ------------------------------
# Team: Bournemouth
# OFF Rating: 1.4210526315789473
# DEF Rating: 1.763157894736842
# ------------------------------
# Team: Newcastle Utd
# OFF Rating: 2.236842105263158
# DEF Rating: 1.631578947368421
# ------------------------------
# Team: Brentford
# OFF Rating: 1.473684210526316
# DEF Rating: 1.7105263157894737
# ------------------------------
# Team: Chelsea
# OFF Rating: 2.026315789473684
# DEF Rating: 1.6578947368421053
# ------------------------------
# Team: Manchester Utd
# OFF Rating: 1.5
# DEF Rating: 1.526315789473684
# ------------------------------
# Team: nan
# OFF Rating: nan
# DEF Rating: nan
# ------------------------------
# Team: Nott'ham Forest
# OFF Rating: 1.2894736842105263
# DEF Rating: 1.763157894736842
# ------------------------------
# Team: Fulham
# OFF Rating: 1.4473684210526314
# DEF Rating: 1.6052631578947367
# ------------------------------
# Team: Liverpool
# OFF Rating: 2.263157894736842
# DEF Rating: 1.0789473684210527
# ------------------------------
# Team: Wolves
# OFF Rating: 1.3157894736842106
# DEF Rating: 1.7105263157894737
# ------------------------------
# Team: Tottenham
# OFF Rating: 1.9473684210526314
# DEF Rating: 1.6052631578947367
# ------------------------------
# Team: Manchester City
# OFF Rating: 2.526315789473684
# DEF Rating: 0.894736842105263
# ------------------------------
# Team: Aston Villa
# OFF Rating: 2.0
# DEF Rating: 1.6052631578947367
# ------------------------------
# Team: West Ham
# OFF Rating: 1.5789473684210527
# DEF Rating: 1.9473684210526314
# ------------------------------
# Team: Crystal Palace
# OFF Rating: 1.5
# DEF Rating: 1.526315789473684
# ------------------------------
# Team: Luton Town
# OFF Rating: 1.3684210526315788
# DEF Rating: 2.236842105263158
# ------------------------------

# %%
# Scrape the next round of fixtures

#start by scraping all fixtures for the season

fixtures = pd.read_html('https://fbref.com/en/comps/9/2023-2024/schedule/2023-2024-Premier-League-Scores-and-Fixtures', # allows us to read tables from html - paste in the link and css selectors
                  attrs={"id":"sched_2023-2024_9_1"})[0] # add the [0] to return the first item in the list - looks better

# %%
fixtures.head()
# Out:
#     Wk  Day        Date   Time           Home   xG Score  xG.1  \
# 0  1.0  Fri  2023-08-11  20:00        Burnley  0.3   0–3   1.9
# 1  1.0  Sat  2023-08-12  12:30        Arsenal  0.8   2–1   1.2
# 2  1.0  Sat  2023-08-12  15:00        Everton  2.7   0–1   1.5
# 3  1.0  Sat  2023-08-12  15:00  Sheffield Utd  0.5   0–1   1.9
# 4  1.0  Sat  2023-08-12  15:00       Brighton  4.0   4–1   1.5
#
#               Away  Attendance                                   Venue  \
# 0  Manchester City     21572.0                               Turf Moor
# 1  Nott'ham Forest     59984.0                        Emirates Stadium
# 2           Fulham     39940.0                           Goodison Park
# 3   Crystal Palace     31194.0                            Bramall Lane
# 4       Luton Town     31872.0  The American Express Community Stadium
#
#           Referee  Match Report  Notes
# 0    Craig Pawson  Match Report    NaN
# 1  Michael Oliver  Match Report    NaN
# 2  Stuart Attwell  Match Report    NaN
# 3     John Brooks  Match Report    NaN
# 4     David Coote  Match Report    NaN

# %%
#return a certain week of fixtures - we'll use the last gameweek

fixtures_by_gw = fixtures[fixtures['Wk'] == 38.0]

fixtures_by_gw
# Out:
#        Wk  Day        Date   Time             Home   xG Score  xG.1  \
# 413  38.0  Sun  2024-05-19  16:00       Luton Town  2.0   2–4   1.1
# 414  38.0  Sun  2024-05-19  16:00    Sheffield Utd  1.0   0–3   3.1
# 415  38.0  Sun  2024-05-19  16:00  Manchester City  1.9   3–1   0.4
# 416  38.0  Sun  2024-05-19  16:00          Arsenal  2.9   2–1   0.6
# 417  38.0  Sun  2024-05-19  16:00         Brighton  1.7   0–2   1.3
# 418  38.0  Sun  2024-05-19  16:00        Brentford  1.1   2–4   3.4
# 419  38.0  Sun  2024-05-19  16:00          Chelsea  1.1   2–1   2.2
# 420  38.0  Sun  2024-05-19  16:00   Crystal Palace  2.5   5–0   0.9
# 421  38.0  Sun  2024-05-19  16:00        Liverpool  4.5   2–0   0.5
# 422  38.0  Sun  2024-05-19  16:00          Burnley  1.2   1–2   1.7
#
#                 Away  Attendance                                   Venue  \
# 413           Fulham     12027.0                 Kenilworth Road Stadium
# 414        Tottenham     29116.0                            Bramall Lane
# 415         West Ham     55097.0                          Etihad Stadium
# 416          Everton     60312.0                        Emirates Stadium
# 417   Manchester Utd     31662.0  The American Express Community Stadium
# 418    Newcastle Utd     17124.0                 Gtech Community Stadium
# 419      Bournemouth     39724.0                         Stamford Bridge
# 420      Aston Villa     25191.0                           Selhurst Park
# 421           Wolves     60059.0                                 Anfield
# 422  Nott'ham Forest     21109.0                               Turf Moor
#
#             Referee  Match Report  Notes
# 413    Matt Donohue  Match Report    NaN
# 414     Andy Madley  Match Report    NaN
# 415     John Brooks  Match Report    NaN
# 416  Michael Oliver  Match Report    NaN
# 417    Craig Pawson  Match Report    NaN
# 418    Simon Hooper  Match Report    NaN
# 419  Anthony Taylor  Match Report    NaN
# 420     Darren Bond  Match Report    NaN
# 421  Chris Kavanagh  Match Report    NaN
# 422    Graham Scott  Match Report    NaN

# %%
# filter for only the home and away teams per fixture

fixtures_nr = fixtures_by_gw[['Home', 'Away']]

fixtures_nr
# Out:
#                 Home             Away
# 413       Luton Town           Fulham
# 414    Sheffield Utd        Tottenham
# 415  Manchester City         West Ham
# 416          Arsenal          Everton
# 417         Brighton   Manchester Utd
# 418        Brentford    Newcastle Utd
# 419          Chelsea      Bournemouth
# 420   Crystal Palace      Aston Villa
# 421        Liverpool           Wolves
# 422          Burnley  Nott'ham Forest

# %%
#Now time to run the match simulator for each fixture in GW38

import pandas as pd
import numpy as np
from scipy.stats import poisson
from IPython.display import display



# Define the number of goals for the Poisson matrix
number_of_goals = 7

# Define functions

#create 2 poisson dist for number of goals each team will score
def simulate_poisson_distribution(home_team_xg, away_team_xg):
    score_matrix = np.zeros((number_of_goals, number_of_goals))
    for home_goals in range(number_of_goals):
        for away_goals in range(number_of_goals):
            home_prob = poisson.pmf(home_goals, home_team_xg)
            away_prob = poisson.pmf(away_goals, away_team_xg)
            score_matrix[home_goals][away_goals] = home_prob * away_prob
    return score_matrix

#Display the home and away goals on a heatmap grid
def display_heatmap(result_matrix, home_team, away_team):
    result_df = pd.DataFrame(result_matrix, index=range(number_of_goals), columns=range(number_of_goals))
    
    # Use background_gradient with axis=None to apply gradient to individual cells for easy visual
    styled_df = (
        result_df.style
        .background_gradient(cmap="Oranges", axis=None)
        .set_caption(f'<div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>{home_team} vs {away_team}</div>')  # Centered caption with increased font size
        .set_table_attributes('style="text-align: center; width: 800px; height: 400px;"')  # Adjust width and height here
        .format(lambda x: f"{x * 100:.1f}%", na_rep="")  # Format values as percentages
        .set_table_styles(
            [
                {'selector': 'td', 'props': [('text-align', 'center'), ('vertical-align', 'middle'), ('height', '40px')]} ,  # Center text in cells and set height
                {'selector': 'th', 'props': [('text-align', 'center')]}  # Center text in header cells
            ]
        )
    )
    
    # Display the styled DataFrame - for Jupyter Notebook
    display(styled_df)




def calculate_win_draw_probabilities(result_matrix):
    home_win_prob = np.sum(np.tril(result_matrix, -1))
    away_win_prob = np.sum(np.triu(result_matrix, 1))
    draw_prob = np.sum(np.diag(result_matrix))
    return home_win_prob, away_win_prob, draw_prob

# Simulation loop for each fixture
for index, row in fixtures_nr.iterrows():
    home_team = row['Home']
    away_team = row['Away']
    
    # Get xG values
    home_team_xg = team_data.get(home_team, {}).get('OFF Rating', np.nan)
    away_team_xg = team_data.get(away_team, {}).get('DEF Rating', np.nan)
    
    # Check for missing values
    if np.isnan(home_team_xg) or np.isnan(away_team_xg):
        print(f"Missing data for {home_team} vs {away_team}. Skipping this match.")
        continue

    # Run the Poisson simulation
    result_matrix = simulate_poisson_distribution(home_team_xg, away_team_xg)

    # Display the result matrix as a heatmap for the current match
    print(f"\nHeatmap for {home_team} vs {away_team}:")
    display_heatmap(result_matrix, home_team, away_team)
    
    # Calculate 1x2 probabilities
    home_win_prob, away_win_prob, draw_prob = calculate_win_draw_probabilities(result_matrix)
    print(f"\nWin Probabilities for {home_team} vs {away_team}:")
    print(f"Home Win Probability: {home_win_prob:.2f}")
    print(f"Away Win Probability: {away_win_prob:.2f}")
    print(f"Draw Probability: {draw_prob:.2f}")

    # Calculate and print raw prices which is 1 / prob
    home_price = 1 / home_win_prob if home_win_prob > 0 else float('inf')
    draw_price = 1 / draw_prob if draw_prob > 0 else float('inf')
    away_price = 1 / away_win_prob if away_win_prob > 0 else float('inf')

    print("\nRaw Prices:")
    print(f"Home Price : {home_price:.2f}")
    print(f"Draw Price : {draw_price:.2f}")
    print(f"Away Price : {away_price:.2f}")
    print("-" * 40)
# Out:
# Heatmap for Luton Town vs Fulham:
# <style type="text/css">
# #T_484c4 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_484c4 th {
#   text-align: center;
# }
# #T_484c4_row0_col0 {
#   background-color: #fd994d;
#   color: #000000;
# }
# #T_484c4_row0_col1 {
#   background-color: #dc4c03;
#   color: #f1f1f1;
# }
# #T_484c4_row0_col2 {
#   background-color: #f5741f;
#   color: #f1f1f1;
# }
# #T_484c4_row0_col3 {
#   background-color: #fdbf86;
#   color: #000000;
# }
# #T_484c4_row0_col4 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_484c4_row0_col5 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_484c4_row0_col6, #T_484c4_row2_col6 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_484c4_row1_col0 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_484c4_row1_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_484c4_row1_col2 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_484c4_row1_col3, #T_484c4_row2_col0 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_484c4_row1_col4 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_484c4_row1_col5 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_484c4_row1_col6, #T_484c4_row5_col3 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_484c4_row2_col1 {
#   background-color: #e5590a;
#   color: #f1f1f1;
# }
# #T_484c4_row2_col2 {
#   background-color: #f87f2c;
#   color: #f1f1f1;
# }
# #T_484c4_row2_col3 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_484c4_row2_col4 {
#   background-color: #fee7d0;
#   color: #000000;
# }
# #T_484c4_row2_col5 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_484c4_row3_col0 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_484c4_row3_col1 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_484c4_row3_col2 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_484c4_row3_col3 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_484c4_row3_col4 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_484c4_row3_col5, #T_484c4_row4_col4, #T_484c4_row5_col0 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_484c4_row3_col6, #T_484c4_row4_col5, #T_484c4_row5_col4, #T_484c4_row6_col0, #T_484c4_row6_col1, #T_484c4_row6_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_484c4_row4_col0 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_484c4_row4_col1 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_484c4_row4_col2 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_484c4_row4_col3 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_484c4_row4_col6, #T_484c4_row5_col5, #T_484c4_row5_col6, #T_484c4_row6_col3, #T_484c4_row6_col4, #T_484c4_row6_col5, #T_484c4_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_484c4_row5_col1 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_484c4_row5_col2 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# </style>
# <table id="T_484c4" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Luton Town vs Fulham</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_484c4_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_484c4_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_484c4_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_484c4_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_484c4_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_484c4_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_484c4_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_484c4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_484c4_row0_col0" class="data row0 col0" >5.1%</td>
#       <td id="T_484c4_row0_col1" class="data row0 col1" >8.2%</td>
#       <td id="T_484c4_row0_col2" class="data row0 col2" >6.6%</td>
#       <td id="T_484c4_row0_col3" class="data row0 col3" >3.5%</td>
#       <td id="T_484c4_row0_col4" class="data row0 col4" >1.4%</td>
#       <td id="T_484c4_row0_col5" class="data row0 col5" >0.5%</td>
#       <td id="T_484c4_row0_col6" class="data row0 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_484c4_row1_col0" class="data row1 col0" >7.0%</td>
#       <td id="T_484c4_row1_col1" class="data row1 col1" >11.2%</td>
#       <td id="T_484c4_row1_col2" class="data row1 col2" >9.0%</td>
#       <td id="T_484c4_row1_col3" class="data row1 col3" >4.8%</td>
#       <td id="T_484c4_row1_col4" class="data row1 col4" >1.9%</td>
#       <td id="T_484c4_row1_col5" class="data row1 col5" >0.6%</td>
#       <td id="T_484c4_row1_col6" class="data row1 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_484c4_row2_col0" class="data row2 col0" >4.8%</td>
#       <td id="T_484c4_row2_col1" class="data row2 col1" >7.7%</td>
#       <td id="T_484c4_row2_col2" class="data row2 col2" >6.2%</td>
#       <td id="T_484c4_row2_col3" class="data row2 col3" >3.3%</td>
#       <td id="T_484c4_row2_col4" class="data row2 col4" >1.3%</td>
#       <td id="T_484c4_row2_col5" class="data row2 col5" >0.4%</td>
#       <td id="T_484c4_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_484c4_row3_col0" class="data row3 col0" >2.2%</td>
#       <td id="T_484c4_row3_col1" class="data row3 col1" >3.5%</td>
#       <td id="T_484c4_row3_col2" class="data row3 col2" >2.8%</td>
#       <td id="T_484c4_row3_col3" class="data row3 col3" >1.5%</td>
#       <td id="T_484c4_row3_col4" class="data row3 col4" >0.6%</td>
#       <td id="T_484c4_row3_col5" class="data row3 col5" >0.2%</td>
#       <td id="T_484c4_row3_col6" class="data row3 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_484c4_row4_col0" class="data row4 col0" >0.7%</td>
#       <td id="T_484c4_row4_col1" class="data row4 col1" >1.2%</td>
#       <td id="T_484c4_row4_col2" class="data row4 col2" >1.0%</td>
#       <td id="T_484c4_row4_col3" class="data row4 col3" >0.5%</td>
#       <td id="T_484c4_row4_col4" class="data row4 col4" >0.2%</td>
#       <td id="T_484c4_row4_col5" class="data row4 col5" >0.1%</td>
#       <td id="T_484c4_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_484c4_row5_col0" class="data row5 col0" >0.2%</td>
#       <td id="T_484c4_row5_col1" class="data row5 col1" >0.3%</td>
#       <td id="T_484c4_row5_col2" class="data row5 col2" >0.3%</td>
#       <td id="T_484c4_row5_col3" class="data row5 col3" >0.1%</td>
#       <td id="T_484c4_row5_col4" class="data row5 col4" >0.1%</td>
#       <td id="T_484c4_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_484c4_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_484c4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_484c4_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_484c4_row6_col1" class="data row6 col1" >0.1%</td>
#       <td id="T_484c4_row6_col2" class="data row6 col2" >0.1%</td>
#       <td id="T_484c4_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_484c4_row6_col4" class="data row6 col4" >0.0%</td>
#       <td id="T_484c4_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_484c4_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Luton Town vs Fulham:
# Home Win Probability: 0.33
# Away Win Probability: 0.43
# Draw Probability: 0.24
#
# Raw Prices:
# Home Price : 3.07
# Draw Price : 4.13
# Away Price : 2.33
# ----------------------------------------
#
# Heatmap for Sheffield Utd vs Tottenham:
# <style type="text/css">
# #T_c7c96 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_c7c96 th {
#   text-align: center;
# }
# #T_c7c96_row0_col0 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_c7c96_row0_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_c7c96_row0_col2 {
#   background-color: #c34002;
#   color: #f1f1f1;
# }
# #T_c7c96_row0_col3 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_c7c96_row0_col4 {
#   background-color: #fedebd;
#   color: #000000;
# }
# #T_c7c96_row0_col5, #T_c7c96_row3_col3 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_c7c96_row0_col6, #T_c7c96_row1_col6, #T_c7c96_row4_col3 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_c7c96_row1_col0 {
#   background-color: #f67824;
#   color: #f1f1f1;
# }
# #T_c7c96_row1_col1 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_c7c96_row1_col2 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_c7c96_row1_col3 {
#   background-color: #fda863;
#   color: #000000;
# }
# #T_c7c96_row1_col4 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_c7c96_row1_col5 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_c7c96_row2_col0 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_c7c96_row2_col1 {
#   background-color: #fda159;
#   color: #000000;
# }
# #T_c7c96_row2_col2 {
#   background-color: #fdb77a;
#   color: #000000;
# }
# #T_c7c96_row2_col3 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_c7c96_row2_col4 {
#   background-color: #feeddb;
#   color: #000000;
# }
# #T_c7c96_row2_col5, #T_c7c96_row4_col2 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_c7c96_row2_col6, #T_c7c96_row3_col5, #T_c7c96_row4_col4, #T_c7c96_row5_col1, #T_c7c96_row5_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_c7c96_row3_col0 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_c7c96_row3_col1 {
#   background-color: #fee5cc;
#   color: #000000;
# }
# #T_c7c96_row3_col2 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_c7c96_row3_col4 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_c7c96_row3_col6, #T_c7c96_row4_col5, #T_c7c96_row4_col6, #T_c7c96_row5_col0, #T_c7c96_row5_col3, #T_c7c96_row5_col4, #T_c7c96_row5_col5, #T_c7c96_row5_col6, #T_c7c96_row6_col0, #T_c7c96_row6_col1, #T_c7c96_row6_col2, #T_c7c96_row6_col3, #T_c7c96_row6_col4, #T_c7c96_row6_col5, #T_c7c96_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_c7c96_row4_col0 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_c7c96_row4_col1 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# </style>
# <table id="T_c7c96" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Sheffield Utd vs Tottenham</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7c96_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_c7c96_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_c7c96_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_c7c96_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_c7c96_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_c7c96_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_c7c96_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7c96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c7c96_row0_col0" class="data row0 col0" >8.0%</td>
#       <td id="T_c7c96_row0_col1" class="data row0 col1" >12.8%</td>
#       <td id="T_c7c96_row0_col2" class="data row0 col2" >10.3%</td>
#       <td id="T_c7c96_row0_col3" class="data row0 col3" >5.5%</td>
#       <td id="T_c7c96_row0_col4" class="data row0 col4" >2.2%</td>
#       <td id="T_c7c96_row0_col5" class="data row0 col5" >0.7%</td>
#       <td id="T_c7c96_row0_col6" class="data row0 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c7c96_row1_col0" class="data row1 col0" >7.4%</td>
#       <td id="T_c7c96_row1_col1" class="data row1 col1" >11.8%</td>
#       <td id="T_c7c96_row1_col2" class="data row1 col2" >9.5%</td>
#       <td id="T_c7c96_row1_col3" class="data row1 col3" >5.1%</td>
#       <td id="T_c7c96_row1_col4" class="data row1 col4" >2.0%</td>
#       <td id="T_c7c96_row1_col5" class="data row1 col5" >0.7%</td>
#       <td id="T_c7c96_row1_col6" class="data row1 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c7c96_row2_col0" class="data row2 col0" >3.4%</td>
#       <td id="T_c7c96_row2_col1" class="data row2 col1" >5.4%</td>
#       <td id="T_c7c96_row2_col2" class="data row2 col2" >4.4%</td>
#       <td id="T_c7c96_row2_col3" class="data row2 col3" >2.3%</td>
#       <td id="T_c7c96_row2_col4" class="data row2 col4" >0.9%</td>
#       <td id="T_c7c96_row2_col5" class="data row2 col5" >0.3%</td>
#       <td id="T_c7c96_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c7c96_row3_col0" class="data row3 col0" >1.0%</td>
#       <td id="T_c7c96_row3_col1" class="data row3 col1" >1.7%</td>
#       <td id="T_c7c96_row3_col2" class="data row3 col2" >1.3%</td>
#       <td id="T_c7c96_row3_col3" class="data row3 col3" >0.7%</td>
#       <td id="T_c7c96_row3_col4" class="data row3 col4" >0.3%</td>
#       <td id="T_c7c96_row3_col5" class="data row3 col5" >0.1%</td>
#       <td id="T_c7c96_row3_col6" class="data row3 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c7c96_row4_col0" class="data row4 col0" >0.2%</td>
#       <td id="T_c7c96_row4_col1" class="data row4 col1" >0.4%</td>
#       <td id="T_c7c96_row4_col2" class="data row4 col2" >0.3%</td>
#       <td id="T_c7c96_row4_col3" class="data row4 col3" >0.2%</td>
#       <td id="T_c7c96_row4_col4" class="data row4 col4" >0.1%</td>
#       <td id="T_c7c96_row4_col5" class="data row4 col5" >0.0%</td>
#       <td id="T_c7c96_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c7c96_row5_col0" class="data row5 col0" >0.0%</td>
#       <td id="T_c7c96_row5_col1" class="data row5 col1" >0.1%</td>
#       <td id="T_c7c96_row5_col2" class="data row5 col2" >0.1%</td>
#       <td id="T_c7c96_row5_col3" class="data row5 col3" >0.0%</td>
#       <td id="T_c7c96_row5_col4" class="data row5 col4" >0.0%</td>
#       <td id="T_c7c96_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_c7c96_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_c7c96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c7c96_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_c7c96_row6_col1" class="data row6 col1" >0.0%</td>
#       <td id="T_c7c96_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_c7c96_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_c7c96_row6_col4" class="data row6 col4" >0.0%</td>
#       <td id="T_c7c96_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_c7c96_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Sheffield Utd vs Tottenham:
# Home Win Probability: 0.22
# Away Win Probability: 0.53
# Draw Probability: 0.25
#
# Raw Prices:
# Home Price : 4.63
# Draw Price : 4.00
# Away Price : 1.88
# ----------------------------------------
#
# Heatmap for Manchester City vs West Ham:
# <style type="text/css">
# #T_dd3ac td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_dd3ac th {
#   text-align: center;
# }
# #T_dd3ac_row0_col0, #T_dd3ac_row4_col4 {
#   background-color: #fee0c3;
#   color: #000000;
# }
# #T_dd3ac_row0_col1 {
#   background-color: #fdc088;
#   color: #000000;
# }
# #T_dd3ac_row0_col2, #T_dd3ac_row2_col4 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_dd3ac_row0_col3 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_dd3ac_row0_col4, #T_dd3ac_row1_col5 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_dd3ac_row0_col5, #T_dd3ac_row2_col6 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_dd3ac_row0_col6, #T_dd3ac_row6_col5 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_dd3ac_row1_col0 {
#   background-color: #fda660;
#   color: #000000;
# }
# #T_dd3ac_row1_col1 {
#   background-color: #c84202;
#   color: #f1f1f1;
# }
# #T_dd3ac_row1_col2 {
#   background-color: #d04501;
#   color: #f1f1f1;
# }
# #T_dd3ac_row1_col3 {
#   background-color: #fd8e3d;
#   color: #f1f1f1;
# }
# #T_dd3ac_row1_col4 {
#   background-color: #fdd2a6;
#   color: #000000;
# }
# #T_dd3ac_row1_col6 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_dd3ac_row2_col0 {
#   background-color: #fc8a39;
#   color: #f1f1f1;
# }
# #T_dd3ac_row2_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_dd3ac_row2_col2 {
#   background-color: #862a04;
#   color: #f1f1f1;
# }
# #T_dd3ac_row2_col3 {
#   background-color: #f06712;
#   color: #f1f1f1;
# }
# #T_dd3ac_row2_col5 {
#   background-color: #fee7d1;
#   color: #000000;
# }
# #T_dd3ac_row3_col0 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_dd3ac_row3_col1 {
#   background-color: #b33b02;
#   color: #f1f1f1;
# }
# #T_dd3ac_row3_col2 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_dd3ac_row3_col3, #T_dd3ac_row4_col1 {
#   background-color: #fa8532;
#   color: #f1f1f1;
# }
# #T_dd3ac_row3_col4 {
#   background-color: #fdcfa0;
#   color: #000000;
# }
# #T_dd3ac_row3_col5 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_dd3ac_row3_col6, #T_dd3ac_row5_col5, #T_dd3ac_row6_col4 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_dd3ac_row4_col0 {
#   background-color: #fdca99;
#   color: #000000;
# }
# #T_dd3ac_row4_col2 {
#   background-color: #fb8836;
#   color: #f1f1f1;
# }
# #T_dd3ac_row4_col3 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_dd3ac_row4_col5 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_dd3ac_row4_col6 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_dd3ac_row5_col0 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_dd3ac_row5_col1 {
#   background-color: #fdcd9c;
#   color: #000000;
# }
# #T_dd3ac_row5_col2 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_dd3ac_row5_col3 {
#   background-color: #fedfc0;
#   color: #000000;
# }
# #T_dd3ac_row5_col4 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_dd3ac_row5_col6 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_dd3ac_row6_col0 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_dd3ac_row6_col1, #T_dd3ac_row6_col2 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_dd3ac_row6_col3 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_dd3ac_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# </style>
# <table id="T_dd3ac" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Manchester City vs West Ham</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd3ac_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_dd3ac_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_dd3ac_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_dd3ac_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_dd3ac_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_dd3ac_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_dd3ac_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd3ac_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd3ac_row0_col0" class="data row0 col0" >1.1%</td>
#       <td id="T_dd3ac_row0_col1" class="data row0 col1" >2.2%</td>
#       <td id="T_dd3ac_row0_col2" class="data row0 col2" >2.2%</td>
#       <td id="T_dd3ac_row0_col3" class="data row0 col3" >1.4%</td>
#       <td id="T_dd3ac_row0_col4" class="data row0 col4" >0.7%</td>
#       <td id="T_dd3ac_row0_col5" class="data row0 col5" >0.3%</td>
#       <td id="T_dd3ac_row0_col6" class="data row0 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd3ac_row1_col0" class="data row1 col0" >2.9%</td>
#       <td id="T_dd3ac_row1_col1" class="data row1 col1" >5.6%</td>
#       <td id="T_dd3ac_row1_col2" class="data row1 col2" >5.5%</td>
#       <td id="T_dd3ac_row1_col3" class="data row1 col3" >3.5%</td>
#       <td id="T_dd3ac_row1_col4" class="data row1 col4" >1.7%</td>
#       <td id="T_dd3ac_row1_col5" class="data row1 col5" >0.7%</td>
#       <td id="T_dd3ac_row1_col6" class="data row1 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd3ac_row2_col0" class="data row2 col0" >3.6%</td>
#       <td id="T_dd3ac_row2_col1" class="data row2 col1" >7.1%</td>
#       <td id="T_dd3ac_row2_col2" class="data row2 col2" >6.9%</td>
#       <td id="T_dd3ac_row2_col3" class="data row2 col3" >4.5%</td>
#       <td id="T_dd3ac_row2_col4" class="data row2 col4" >2.2%</td>
#       <td id="T_dd3ac_row2_col5" class="data row2 col5" >0.8%</td>
#       <td id="T_dd3ac_row2_col6" class="data row2 col6" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd3ac_row3_col0" class="data row3 col0" >3.1%</td>
#       <td id="T_dd3ac_row3_col1" class="data row3 col1" >6.0%</td>
#       <td id="T_dd3ac_row3_col2" class="data row3 col2" >5.8%</td>
#       <td id="T_dd3ac_row3_col3" class="data row3 col3" >3.8%</td>
#       <td id="T_dd3ac_row3_col4" class="data row3 col4" >1.8%</td>
#       <td id="T_dd3ac_row3_col5" class="data row3 col5" >0.7%</td>
#       <td id="T_dd3ac_row3_col6" class="data row3 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd3ac_row4_col0" class="data row4 col0" >1.9%</td>
#       <td id="T_dd3ac_row4_col1" class="data row4 col1" >3.8%</td>
#       <td id="T_dd3ac_row4_col2" class="data row4 col2" >3.7%</td>
#       <td id="T_dd3ac_row4_col3" class="data row4 col3" >2.4%</td>
#       <td id="T_dd3ac_row4_col4" class="data row4 col4" >1.2%</td>
#       <td id="T_dd3ac_row4_col5" class="data row4 col5" >0.5%</td>
#       <td id="T_dd3ac_row4_col6" class="data row4 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd3ac_row5_col0" class="data row5 col0" >1.0%</td>
#       <td id="T_dd3ac_row5_col1" class="data row5 col1" >1.9%</td>
#       <td id="T_dd3ac_row5_col2" class="data row5 col2" >1.9%</td>
#       <td id="T_dd3ac_row5_col3" class="data row5 col3" >1.2%</td>
#       <td id="T_dd3ac_row5_col4" class="data row5 col4" >0.6%</td>
#       <td id="T_dd3ac_row5_col5" class="data row5 col5" >0.2%</td>
#       <td id="T_dd3ac_row5_col6" class="data row5 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_dd3ac_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd3ac_row6_col0" class="data row6 col0" >0.4%</td>
#       <td id="T_dd3ac_row6_col1" class="data row6 col1" >0.8%</td>
#       <td id="T_dd3ac_row6_col2" class="data row6 col2" >0.8%</td>
#       <td id="T_dd3ac_row6_col3" class="data row6 col3" >0.5%</td>
#       <td id="T_dd3ac_row6_col4" class="data row6 col4" >0.2%</td>
#       <td id="T_dd3ac_row6_col5" class="data row6 col5" >0.1%</td>
#       <td id="T_dd3ac_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Manchester City vs West Ham:
# Home Win Probability: 0.50
# Away Win Probability: 0.30
# Draw Probability: 0.19
#
# Raw Prices:
# Home Price : 2.02
# Draw Price : 5.31
# Away Price : 3.37
# ----------------------------------------
#
# Heatmap for Arsenal vs Everton:
# <style type="text/css">
# #T_f3a42 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_f3a42 th {
#   text-align: center;
# }
# #T_f3a42_row0_col0 {
#   background-color: #fdce9e;
#   color: #000000;
# }
# #T_f3a42_row0_col1 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_f3a42_row0_col2 {
#   background-color: #fdd3a9;
#   color: #000000;
# }
# #T_f3a42_row0_col3 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_f3a42_row0_col4 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_f3a42_row0_col5, #T_f3a42_row6_col4 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_f3a42_row0_col6, #T_f3a42_row4_col6, #T_f3a42_row5_col6, #T_f3a42_row6_col5, #T_f3a42_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_f3a42_row1_col0 {
#   background-color: #f16913;
#   color: #f1f1f1;
# }
# #T_f3a42_row1_col1 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_f3a42_row1_col2 {
#   background-color: #f77b28;
#   color: #f1f1f1;
# }
# #T_f3a42_row1_col3 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_f3a42_row1_col4 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_f3a42_row1_col5, #T_f3a42_row3_col5, #T_f3a42_row5_col4 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_f3a42_row1_col6, #T_f3a42_row2_col6, #T_f3a42_row3_col6, #T_f3a42_row5_col5 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_f3a42_row2_col0 {
#   background-color: #da4902;
#   color: #f1f1f1;
# }
# #T_f3a42_row2_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_f3a42_row2_col2 {
#   background-color: #e85d0c;
#   color: #f1f1f1;
# }
# #T_f3a42_row2_col3 {
#   background-color: #fdc38d;
#   color: #000000;
# }
# #T_f3a42_row2_col4 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_f3a42_row2_col5, #T_f3a42_row6_col3 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_f3a42_row3_col0 {
#   background-color: #f4711c;
#   color: #f1f1f1;
# }
# #T_f3a42_row3_col1 {
#   background-color: #c54102;
#   color: #f1f1f1;
# }
# #T_f3a42_row3_col2 {
#   background-color: #f98230;
#   color: #f1f1f1;
# }
# #T_f3a42_row3_col3 {
#   background-color: #fdd2a6;
#   color: #000000;
# }
# #T_f3a42_row3_col4 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_f3a42_row4_col0 {
#   background-color: #fdb373;
#   color: #000000;
# }
# #T_f3a42_row4_col1 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_f3a42_row4_col2 {
#   background-color: #fdbd83;
#   color: #000000;
# }
# #T_f3a42_row4_col3 {
#   background-color: #fee3c8;
#   color: #000000;
# }
# #T_f3a42_row4_col4 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_f3a42_row4_col5 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_f3a42_row5_col0 {
#   background-color: #fedebf;
#   color: #000000;
# }
# #T_f3a42_row5_col1 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_f3a42_row5_col2 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_f3a42_row5_col3, #T_f3a42_row6_col0 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_f3a42_row6_col1 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_f3a42_row6_col2 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# </style>
# <table id="T_f3a42" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Arsenal vs Everton</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3a42_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_f3a42_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_f3a42_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_f3a42_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_f3a42_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_f3a42_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_f3a42_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3a42_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3a42_row0_col0" class="data row0 col0" >2.4%</td>
#       <td id="T_f3a42_row0_col1" class="data row0 col1" >3.2%</td>
#       <td id="T_f3a42_row0_col2" class="data row0 col2" >2.1%</td>
#       <td id="T_f3a42_row0_col3" class="data row0 col3" >1.0%</td>
#       <td id="T_f3a42_row0_col4" class="data row0 col4" >0.3%</td>
#       <td id="T_f3a42_row0_col5" class="data row0 col5" >0.1%</td>
#       <td id="T_f3a42_row0_col6" class="data row0 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f3a42_row1_col0" class="data row1 col0" >5.7%</td>
#       <td id="T_f3a42_row1_col1" class="data row1 col1" >7.7%</td>
#       <td id="T_f3a42_row1_col2" class="data row1 col2" >5.1%</td>
#       <td id="T_f3a42_row1_col3" class="data row1 col3" >2.3%</td>
#       <td id="T_f3a42_row1_col4" class="data row1 col4" >0.8%</td>
#       <td id="T_f3a42_row1_col5" class="data row1 col5" >0.2%</td>
#       <td id="T_f3a42_row1_col6" class="data row1 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f3a42_row2_col0" class="data row2 col0" >6.8%</td>
#       <td id="T_f3a42_row2_col1" class="data row2 col1" >9.2%</td>
#       <td id="T_f3a42_row2_col2" class="data row2 col2" >6.2%</td>
#       <td id="T_f3a42_row2_col3" class="data row2 col3" >2.8%</td>
#       <td id="T_f3a42_row2_col4" class="data row2 col4" >0.9%</td>
#       <td id="T_f3a42_row2_col5" class="data row2 col5" >0.2%</td>
#       <td id="T_f3a42_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f3a42_row3_col0" class="data row3 col0" >5.5%</td>
#       <td id="T_f3a42_row3_col1" class="data row3 col1" >7.3%</td>
#       <td id="T_f3a42_row3_col2" class="data row3 col2" >4.9%</td>
#       <td id="T_f3a42_row3_col3" class="data row3 col3" >2.2%</td>
#       <td id="T_f3a42_row3_col4" class="data row3 col4" >0.7%</td>
#       <td id="T_f3a42_row3_col5" class="data row3 col5" >0.2%</td>
#       <td id="T_f3a42_row3_col6" class="data row3 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f3a42_row4_col0" class="data row4 col0" >3.3%</td>
#       <td id="T_f3a42_row4_col1" class="data row4 col1" >4.4%</td>
#       <td id="T_f3a42_row4_col2" class="data row4 col2" >2.9%</td>
#       <td id="T_f3a42_row4_col3" class="data row4 col3" >1.3%</td>
#       <td id="T_f3a42_row4_col4" class="data row4 col4" >0.4%</td>
#       <td id="T_f3a42_row4_col5" class="data row4 col5" >0.1%</td>
#       <td id="T_f3a42_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f3a42_row5_col0" class="data row5 col0" >1.6%</td>
#       <td id="T_f3a42_row5_col1" class="data row5 col1" >2.1%</td>
#       <td id="T_f3a42_row5_col2" class="data row5 col2" >1.4%</td>
#       <td id="T_f3a42_row5_col3" class="data row5 col3" >0.6%</td>
#       <td id="T_f3a42_row5_col4" class="data row5 col4" >0.2%</td>
#       <td id="T_f3a42_row5_col5" class="data row5 col5" >0.1%</td>
#       <td id="T_f3a42_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_f3a42_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f3a42_row6_col0" class="data row6 col0" >0.6%</td>
#       <td id="T_f3a42_row6_col1" class="data row6 col1" >0.8%</td>
#       <td id="T_f3a42_row6_col2" class="data row6 col2" >0.6%</td>
#       <td id="T_f3a42_row6_col3" class="data row6 col3" >0.3%</td>
#       <td id="T_f3a42_row6_col4" class="data row6 col4" >0.1%</td>
#       <td id="T_f3a42_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_f3a42_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Arsenal vs Everton:
# Home Win Probability: 0.60
# Away Win Probability: 0.20
# Draw Probability: 0.19
#
# Raw Prices:
# Home Price : 1.68
# Draw Price : 5.29
# Away Price : 4.92
# ----------------------------------------
#
# Heatmap for Brighton vs Manchester Utd:
# <style type="text/css">
# #T_637e9 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_637e9 th {
#   text-align: center;
# }
# #T_637e9_row0_col0 {
#   background-color: #fd9a4e;
#   color: #000000;
# }
# #T_637e9_row0_col1 {
#   background-color: #e4580a;
#   color: #f1f1f1;
# }
# #T_637e9_row0_col2 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_637e9_row0_col3, #T_637e9_row3_col2 {
#   background-color: #fdcb9b;
#   color: #000000;
# }
# #T_637e9_row0_col4 {
#   background-color: #fee9d3;
#   color: #000000;
# }
# #T_637e9_row0_col5, #T_637e9_row5_col2 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_637e9_row0_col6, #T_637e9_row1_col6, #T_637e9_row2_col6, #T_637e9_row6_col1 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_637e9_row1_col0 {
#   background-color: #eb610f;
#   color: #f1f1f1;
# }
# #T_637e9_row1_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_637e9_row1_col2 {
#   background-color: #d34601;
#   color: #f1f1f1;
# }
# #T_637e9_row1_col3 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_637e9_row1_col4 {
#   background-color: #fee2c7;
#   color: #000000;
# }
# #T_637e9_row1_col5 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_637e9_row2_col0 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_637e9_row2_col1 {
#   background-color: #de4e05;
#   color: #f1f1f1;
# }
# #T_637e9_row2_col2 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_637e9_row2_col3 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_637e9_row2_col4 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_637e9_row2_col5 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# #T_637e9_row3_col0 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_637e9_row3_col1 {
#   background-color: #fdb576;
#   color: #000000;
# }
# #T_637e9_row3_col3 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_637e9_row3_col4 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_637e9_row3_col5, #T_637e9_row4_col4 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_637e9_row3_col6, #T_637e9_row4_col5, #T_637e9_row5_col4, #T_637e9_row6_col0, #T_637e9_row6_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_637e9_row4_col0 {
#   background-color: #feebd8;
#   color: #000000;
# }
# #T_637e9_row4_col1 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_637e9_row4_col2 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_637e9_row4_col3 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_637e9_row4_col6, #T_637e9_row5_col5, #T_637e9_row5_col6, #T_637e9_row6_col3, #T_637e9_row6_col4, #T_637e9_row6_col5, #T_637e9_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_637e9_row5_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_637e9_row5_col1 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_637e9_row5_col3 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# </style>
# <table id="T_637e9" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Brighton vs Manchester Utd</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_637e9_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_637e9_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_637e9_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_637e9_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_637e9_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_637e9_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_637e9_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_637e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_637e9_row0_col0" class="data row0 col0" >5.1%</td>
#       <td id="T_637e9_row0_col1" class="data row0 col1" >7.8%</td>
#       <td id="T_637e9_row0_col2" class="data row0 col2" >6.0%</td>
#       <td id="T_637e9_row0_col3" class="data row0 col3" >3.0%</td>
#       <td id="T_637e9_row0_col4" class="data row0 col4" >1.2%</td>
#       <td id="T_637e9_row0_col5" class="data row0 col5" >0.4%</td>
#       <td id="T_637e9_row0_col6" class="data row0 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_637e9_row1_col0" class="data row1 col0" >7.4%</td>
#       <td id="T_637e9_row1_col1" class="data row1 col1" >11.3%</td>
#       <td id="T_637e9_row1_col2" class="data row1 col2" >8.6%</td>
#       <td id="T_637e9_row1_col3" class="data row1 col3" >4.4%</td>
#       <td id="T_637e9_row1_col4" class="data row1 col4" >1.7%</td>
#       <td id="T_637e9_row1_col5" class="data row1 col5" >0.5%</td>
#       <td id="T_637e9_row1_col6" class="data row1 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_637e9_row2_col0" class="data row2 col0" >5.4%</td>
#       <td id="T_637e9_row2_col1" class="data row2 col1" >8.2%</td>
#       <td id="T_637e9_row2_col2" class="data row2 col2" >6.2%</td>
#       <td id="T_637e9_row2_col3" class="data row2 col3" >3.2%</td>
#       <td id="T_637e9_row2_col4" class="data row2 col4" >1.2%</td>
#       <td id="T_637e9_row2_col5" class="data row2 col5" >0.4%</td>
#       <td id="T_637e9_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_637e9_row3_col0" class="data row3 col0" >2.6%</td>
#       <td id="T_637e9_row3_col1" class="data row3 col1" >3.9%</td>
#       <td id="T_637e9_row3_col2" class="data row3 col2" >3.0%</td>
#       <td id="T_637e9_row3_col3" class="data row3 col3" >1.5%</td>
#       <td id="T_637e9_row3_col4" class="data row3 col4" >0.6%</td>
#       <td id="T_637e9_row3_col5" class="data row3 col5" >0.2%</td>
#       <td id="T_637e9_row3_col6" class="data row3 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_637e9_row4_col0" class="data row4 col0" >0.9%</td>
#       <td id="T_637e9_row4_col1" class="data row4 col1" >1.4%</td>
#       <td id="T_637e9_row4_col2" class="data row4 col2" >1.1%</td>
#       <td id="T_637e9_row4_col3" class="data row4 col3" >0.6%</td>
#       <td id="T_637e9_row4_col4" class="data row4 col4" >0.2%</td>
#       <td id="T_637e9_row4_col5" class="data row4 col5" >0.1%</td>
#       <td id="T_637e9_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_637e9_row5_col0" class="data row5 col0" >0.3%</td>
#       <td id="T_637e9_row5_col1" class="data row5 col1" >0.4%</td>
#       <td id="T_637e9_row5_col2" class="data row5 col2" >0.3%</td>
#       <td id="T_637e9_row5_col3" class="data row5 col3" >0.2%</td>
#       <td id="T_637e9_row5_col4" class="data row5 col4" >0.1%</td>
#       <td id="T_637e9_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_637e9_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_637e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_637e9_row6_col0" class="data row6 col0" >0.1%</td>
#       <td id="T_637e9_row6_col1" class="data row6 col1" >0.1%</td>
#       <td id="T_637e9_row6_col2" class="data row6 col2" >0.1%</td>
#       <td id="T_637e9_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_637e9_row6_col4" class="data row6 col4" >0.0%</td>
#       <td id="T_637e9_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_637e9_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Brighton vs Manchester Utd:
# Home Win Probability: 0.36
# Away Win Probability: 0.39
# Draw Probability: 0.24
#
# Raw Prices:
# Home Price : 2.78
# Draw Price : 4.10
# Away Price : 2.54
# ----------------------------------------
#
# Heatmap for Brentford vs Newcastle Utd:
# <style type="text/css">
# #T_a99cd td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_a99cd th {
#   text-align: center;
# }
# #T_a99cd_row0_col0 {
#   background-color: #fda35c;
#   color: #000000;
# }
# #T_a99cd_row0_col1 {
#   background-color: #e75b0b;
#   color: #f1f1f1;
# }
# #T_a99cd_row0_col2 {
#   background-color: #f87e2b;
#   color: #f1f1f1;
# }
# #T_a99cd_row0_col3 {
#   background-color: #fdc28b;
#   color: #000000;
# }
# #T_a99cd_row0_col4 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_a99cd_row0_col5, #T_a99cd_row5_col1 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_a99cd_row0_col6, #T_a99cd_row2_col6, #T_a99cd_row6_col1 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_a99cd_row1_col0 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_a99cd_row1_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a99cd_row1_col2 {
#   background-color: #be3f02;
#   color: #f1f1f1;
# }
# #T_a99cd_row1_col3 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_a99cd_row1_col4 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_a99cd_row1_col5, #T_a99cd_row4_col3 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_a99cd_row1_col6, #T_a99cd_row5_col3 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_a99cd_row2_col0 {
#   background-color: #fd9a4e;
#   color: #000000;
# }
# #T_a99cd_row2_col1 {
#   background-color: #db4b03;
#   color: #f1f1f1;
# }
# #T_a99cd_row2_col2 {
#   background-color: #f3701b;
#   color: #f1f1f1;
# }
# #T_a99cd_row2_col3 {
#   background-color: #fdbb81;
#   color: #000000;
# }
# #T_a99cd_row2_col4, #T_a99cd_row4_col1 {
#   background-color: #fee5cb;
#   color: #000000;
# }
# #T_a99cd_row2_col5 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_a99cd_row3_col0 {
#   background-color: #fdd5ad;
#   color: #000000;
# }
# #T_a99cd_row3_col1 {
#   background-color: #fdb271;
#   color: #000000;
# }
# #T_a99cd_row3_col2 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_a99cd_row3_col3 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_a99cd_row3_col4 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_a99cd_row3_col5 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_a99cd_row3_col6, #T_a99cd_row4_col5, #T_a99cd_row5_col4, #T_a99cd_row6_col0, #T_a99cd_row6_col2, #T_a99cd_row6_col3 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_a99cd_row4_col0 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_a99cd_row4_col2 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_a99cd_row4_col4, #T_a99cd_row5_col0 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_a99cd_row4_col6, #T_a99cd_row5_col5, #T_a99cd_row5_col6, #T_a99cd_row6_col4, #T_a99cd_row6_col5, #T_a99cd_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_a99cd_row5_col2 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# </style>
# <table id="T_a99cd" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Brentford vs Newcastle Utd</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a99cd_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_a99cd_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_a99cd_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_a99cd_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_a99cd_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_a99cd_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_a99cd_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a99cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a99cd_row0_col0" class="data row0 col0" >4.5%</td>
#       <td id="T_a99cd_row0_col1" class="data row0 col1" >7.3%</td>
#       <td id="T_a99cd_row0_col2" class="data row0 col2" >6.0%</td>
#       <td id="T_a99cd_row0_col3" class="data row0 col3" >3.2%</td>
#       <td id="T_a99cd_row0_col4" class="data row0 col4" >1.3%</td>
#       <td id="T_a99cd_row0_col5" class="data row0 col5" >0.4%</td>
#       <td id="T_a99cd_row0_col6" class="data row0 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a99cd_row1_col0" class="data row1 col0" >6.6%</td>
#       <td id="T_a99cd_row1_col1" class="data row1 col1" >10.8%</td>
#       <td id="T_a99cd_row1_col2" class="data row1 col2" >8.8%</td>
#       <td id="T_a99cd_row1_col3" class="data row1 col3" >4.8%</td>
#       <td id="T_a99cd_row1_col4" class="data row1 col4" >1.9%</td>
#       <td id="T_a99cd_row1_col5" class="data row1 col5" >0.6%</td>
#       <td id="T_a99cd_row1_col6" class="data row1 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a99cd_row2_col0" class="data row2 col0" >4.9%</td>
#       <td id="T_a99cd_row2_col1" class="data row2 col1" >7.9%</td>
#       <td id="T_a99cd_row2_col2" class="data row2 col2" >6.5%</td>
#       <td id="T_a99cd_row2_col3" class="data row2 col3" >3.5%</td>
#       <td id="T_a99cd_row2_col4" class="data row2 col4" >1.4%</td>
#       <td id="T_a99cd_row2_col5" class="data row2 col5" >0.5%</td>
#       <td id="T_a99cd_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a99cd_row3_col0" class="data row3 col0" >2.4%</td>
#       <td id="T_a99cd_row3_col1" class="data row3 col1" >3.9%</td>
#       <td id="T_a99cd_row3_col2" class="data row3 col2" >3.2%</td>
#       <td id="T_a99cd_row3_col3" class="data row3 col3" >1.7%</td>
#       <td id="T_a99cd_row3_col4" class="data row3 col4" >0.7%</td>
#       <td id="T_a99cd_row3_col5" class="data row3 col5" >0.2%</td>
#       <td id="T_a99cd_row3_col6" class="data row3 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a99cd_row4_col0" class="data row4 col0" >0.9%</td>
#       <td id="T_a99cd_row4_col1" class="data row4 col1" >1.4%</td>
#       <td id="T_a99cd_row4_col2" class="data row4 col2" >1.2%</td>
#       <td id="T_a99cd_row4_col3" class="data row4 col3" >0.6%</td>
#       <td id="T_a99cd_row4_col4" class="data row4 col4" >0.3%</td>
#       <td id="T_a99cd_row4_col5" class="data row4 col5" >0.1%</td>
#       <td id="T_a99cd_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a99cd_row5_col0" class="data row5 col0" >0.3%</td>
#       <td id="T_a99cd_row5_col1" class="data row5 col1" >0.4%</td>
#       <td id="T_a99cd_row5_col2" class="data row5 col2" >0.3%</td>
#       <td id="T_a99cd_row5_col3" class="data row5 col3" >0.2%</td>
#       <td id="T_a99cd_row5_col4" class="data row5 col4" >0.1%</td>
#       <td id="T_a99cd_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_a99cd_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_a99cd_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a99cd_row6_col0" class="data row6 col0" >0.1%</td>
#       <td id="T_a99cd_row6_col1" class="data row6 col1" >0.1%</td>
#       <td id="T_a99cd_row6_col2" class="data row6 col2" >0.1%</td>
#       <td id="T_a99cd_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_a99cd_row6_col4" class="data row6 col4" >0.0%</td>
#       <td id="T_a99cd_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_a99cd_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Brentford vs Newcastle Utd:
# Home Win Probability: 0.35
# Away Win Probability: 0.41
# Draw Probability: 0.24
#
# Raw Prices:
# Home Price : 2.89
# Draw Price : 4.21
# Away Price : 2.42
# ----------------------------------------
#
# Heatmap for Chelsea vs Bournemouth:
# <style type="text/css">
# #T_3a394 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_3a394 th {
#   text-align: center;
# }
# #T_3a394_row0_col0 {
#   background-color: #fdc997;
#   color: #000000;
# }
# #T_3a394_row0_col1 {
#   background-color: #fd9141;
#   color: #000000;
# }
# #T_3a394_row0_col2 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_3a394_row0_col3 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_3a394_row0_col4 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_3a394_row0_col5 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_3a394_row0_col6, #T_3a394_row5_col5, #T_3a394_row6_col4 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_3a394_row1_col0 {
# ...
#
# Raw Prices:
# Home Price : 2.80
# Draw Price : 4.20
# Away Price : 2.48
# ----------------------------------------
#
# Heatmap for Liverpool vs Wolves:
# <style type="text/css">
# #T_1f719 td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_1f719 th {
#   text-align: center;
# }
# #T_1f719_row0_col0 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_1f719_row0_col1 {
#   background-color: #fdab66;
#   color: #000000;
# }
# #T_1f719_row0_col2 {
#   background-color: #fdb97d;
#   color: #000000;
# }
# #T_1f719_row0_col3 {
#   background-color: #fddbb8;
#   color: #000000;
# }
# #T_1f719_row0_col4 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_1f719_row0_col5 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_1f719_row0_col6, #T_1f719_row4_col6 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_1f719_row1_col0 {
#   background-color: #fb8836;
#   color: #f1f1f1;
# }
# #T_1f719_row1_col1 {
#   background-color: #a23503;
#   color: #f1f1f1;
# }
# #T_1f719_row1_col2, #T_1f719_row3_col1 {
#   background-color: #d64701;
#   color: #f1f1f1;
# }
# #T_1f719_row1_col3 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_1f719_row1_col4 {
#   background-color: #fedcbb;
#   color: #000000;
# }
# #T_1f719_row1_col5, #T_1f719_row6_col2 {
#   background-color: #ffeedd;
#   color: #000000;
# }
# #T_1f719_row1_col6, #T_1f719_row2_col6 {
#   background-color: #fff3e7;
#   color: #000000;
# }
# #T_1f719_row2_col0 {
#   background-color: #f57520;
#   color: #f1f1f1;
# }
# #T_1f719_row2_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_1f719_row2_col2 {
#   background-color: #ae3903;
#   color: #f1f1f1;
# }
# #T_1f719_row2_col3 {
#   background-color: #fd9141;
#   color: #000000;
# }
# #T_1f719_row2_col4 {
#   background-color: #fdd7b1;
#   color: #000000;
# }
# #T_1f719_row2_col5 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_1f719_row3_col0 {
#   background-color: #fd9d53;
#   color: #000000;
# }
# #T_1f719_row3_col2 {
#   background-color: #ed6310;
#   color: #f1f1f1;
# }
# #T_1f719_row3_col3, #T_1f719_row4_col2 {
#   background-color: #fdb170;
#   color: #000000;
# }
# #T_1f719_row3_col4 {
#   background-color: #fee1c4;
#   color: #000000;
# }
# #T_1f719_row3_col5 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_1f719_row3_col6, #T_1f719_row5_col5, #T_1f719_row6_col4 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_1f719_row4_col0 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_1f719_row4_col1 {
#   background-color: #fda057;
#   color: #000000;
# }
# #T_1f719_row4_col3 {
#   background-color: #fdd8b2;
#   color: #000000;
# }
# #T_1f719_row4_col4 {
#   background-color: #feebd7;
#   color: #000000;
# }
# #T_1f719_row4_col5 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_1f719_row5_col0 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_1f719_row5_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_1f719_row5_col2 {
#   background-color: #fee0c1;
#   color: #000000;
# }
# #T_1f719_row5_col3 {
#   background-color: #feead6;
#   color: #000000;
# }
# #T_1f719_row5_col4 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_1f719_row5_col6, #T_1f719_row6_col5, #T_1f719_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_1f719_row6_col0 {
#   background-color: #fff0e2;
#   color: #000000;
# }
# #T_1f719_row6_col1 {
#   background-color: #feeddb;
#   color: #000000;
# }
# #T_1f719_row6_col3 {
#   background-color: #fff1e4;
#   color: #000000;
# }
# </style>
# <table id="T_1f719" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Liverpool vs Wolves</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1f719_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_1f719_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_1f719_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_1f719_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_1f719_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_1f719_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_1f719_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1f719_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1f719_row0_col0" class="data row0 col0" >1.9%</td>
#       <td id="T_1f719_row0_col1" class="data row0 col1" >3.2%</td>
#       <td id="T_1f719_row0_col2" class="data row0 col2" >2.8%</td>
#       <td id="T_1f719_row0_col3" class="data row0 col3" >1.6%</td>
#       <td id="T_1f719_row0_col4" class="data row0 col4" >0.7%</td>
#       <td id="T_1f719_row0_col5" class="data row0 col5" >0.2%</td>
#       <td id="T_1f719_row0_col6" class="data row0 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1f719_row1_col0" class="data row1 col0" >4.3%</td>
#       <td id="T_1f719_row1_col1" class="data row1 col1" >7.3%</td>
#       <td id="T_1f719_row1_col2" class="data row1 col2" >6.2%</td>
#       <td id="T_1f719_row1_col3" class="data row1 col3" >3.5%</td>
#       <td id="T_1f719_row1_col4" class="data row1 col4" >1.5%</td>
#       <td id="T_1f719_row1_col5" class="data row1 col5" >0.5%</td>
#       <td id="T_1f719_row1_col6" class="data row1 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1f719_row2_col0" class="data row2 col0" >4.8%</td>
#       <td id="T_1f719_row2_col1" class="data row2 col1" >8.2%</td>
#       <td id="T_1f719_row2_col2" class="data row2 col2" >7.0%</td>
#       <td id="T_1f719_row2_col3" class="data row2 col3" >4.0%</td>
#       <td id="T_1f719_row2_col4" class="data row2 col4" >1.7%</td>
#       <td id="T_1f719_row2_col5" class="data row2 col5" >0.6%</td>
#       <td id="T_1f719_row2_col6" class="data row2 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1f719_row3_col0" class="data row3 col0" >3.6%</td>
#       <td id="T_1f719_row3_col1" class="data row3 col1" >6.2%</td>
#       <td id="T_1f719_row3_col2" class="data row3 col2" >5.3%</td>
#       <td id="T_1f719_row3_col3" class="data row3 col3" >3.0%</td>
#       <td id="T_1f719_row3_col4" class="data row3 col4" >1.3%</td>
#       <td id="T_1f719_row3_col5" class="data row3 col5" >0.4%</td>
#       <td id="T_1f719_row3_col6" class="data row3 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1f719_row4_col0" class="data row4 col0" >2.1%</td>
#       <td id="T_1f719_row4_col1" class="data row4 col1" >3.5%</td>
#       <td id="T_1f719_row4_col2" class="data row4 col2" >3.0%</td>
#       <td id="T_1f719_row4_col3" class="data row4 col3" >1.7%</td>
#       <td id="T_1f719_row4_col4" class="data row4 col4" >0.7%</td>
#       <td id="T_1f719_row4_col5" class="data row4 col5" >0.3%</td>
#       <td id="T_1f719_row4_col6" class="data row4 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1f719_row5_col0" class="data row5 col0" >0.9%</td>
#       <td id="T_1f719_row5_col1" class="data row5 col1" >1.6%</td>
#       <td id="T_1f719_row5_col2" class="data row5 col2" >1.4%</td>
#       <td id="T_1f719_row5_col3" class="data row5 col3" >0.8%</td>
#       <td id="T_1f719_row5_col4" class="data row5 col4" >0.3%</td>
#       <td id="T_1f719_row5_col5" class="data row5 col5" >0.1%</td>
#       <td id="T_1f719_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_1f719_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1f719_row6_col0" class="data row6 col0" >0.4%</td>
#       <td id="T_1f719_row6_col1" class="data row6 col1" >0.6%</td>
#       <td id="T_1f719_row6_col2" class="data row6 col2" >0.5%</td>
#       <td id="T_1f719_row6_col3" class="data row6 col3" >0.3%</td>
#       <td id="T_1f719_row6_col4" class="data row6 col4" >0.1%</td>
#       <td id="T_1f719_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_1f719_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Liverpool vs Wolves:
# Home Win Probability: 0.50
# Away Win Probability: 0.29
# Draw Probability: 0.20
#
# Raw Prices:
# Home Price : 2.01
# Draw Price : 4.98
# Away Price : 3.43
# ----------------------------------------
#
# Heatmap for Burnley vs Nott'ham Forest:
# <style type="text/css">
# #T_e0e8a td {
#   text-align: center;
#   vertical-align: middle;
#   height: 40px;
# }
# #T_e0e8a th {
#   text-align: center;
# }
# #T_e0e8a_row0_col0 {
#   background-color: #fb8634;
#   color: #f1f1f1;
# }
# #T_e0e8a_row0_col1 {
#   background-color: #952f03;
#   color: #f1f1f1;
# }
# #T_e0e8a_row0_col2 {
#   background-color: #bd3e02;
#   color: #f1f1f1;
# }
# #T_e0e8a_row0_col3 {
#   background-color: #fd9344;
#   color: #000000;
# }
# #T_e0e8a_row0_col4 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_e0e8a_row0_col5 {
#   background-color: #feecda;
#   color: #000000;
# }
# #T_e0e8a_row0_col6 {
#   background-color: #fff3e6;
#   color: #000000;
# }
# #T_e0e8a_row1_col0 {
#   background-color: #f67925;
#   color: #f1f1f1;
# }
# #T_e0e8a_row1_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_e0e8a_row1_col2 {
#   background-color: #a43503;
#   color: #f1f1f1;
# }
# #T_e0e8a_row1_col3 {
#   background-color: #fb8836;
#   color: #f1f1f1;
# }
# #T_e0e8a_row1_col4 {
#   background-color: #fdd4aa;
#   color: #000000;
# }
# #T_e0e8a_row1_col5 {
#   background-color: #feecd9;
#   color: #000000;
# }
# #T_e0e8a_row1_col6, #T_e0e8a_row4_col3 {
#   background-color: #fff2e6;
#   color: #000000;
# }
# #T_e0e8a_row2_col0 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_e0e8a_row2_col1 {
#   background-color: #f9812e;
#   color: #f1f1f1;
# }
# #T_e0e8a_row2_col2 {
#   background-color: #fd9446;
#   color: #000000;
# }
# #T_e0e8a_row2_col3 {
#   background-color: #fdc895;
#   color: #000000;
# }
# #T_e0e8a_row2_col4 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# #T_e0e8a_row2_col5, #T_e0e8a_row3_col4, #T_e0e8a_row4_col2 {
#   background-color: #fff0e1;
#   color: #000000;
# }
# #T_e0e8a_row2_col6, #T_e0e8a_row3_col5, #T_e0e8a_row4_col4 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_e0e8a_row3_col0 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_e0e8a_row3_col1 {
#   background-color: #fddab6;
#   color: #000000;
# }
# #T_e0e8a_row3_col2 {
#   background-color: #fedebf;
#   color: #000000;
# }
# #T_e0e8a_row3_col3 {
#   background-color: #fee9d4;
#   color: #000000;
# }
# #T_e0e8a_row3_col6, #T_e0e8a_row4_col5, #T_e0e8a_row5_col0, #T_e0e8a_row5_col3 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_e0e8a_row4_col0 {
#   background-color: #fff2e5;
#   color: #000000;
# }
# #T_e0e8a_row4_col1 {
#   background-color: #ffefdf;
#   color: #000000;
# }
# #T_e0e8a_row4_col6, #T_e0e8a_row5_col4, #T_e0e8a_row5_col5, #T_e0e8a_row5_col6, #T_e0e8a_row6_col0, #T_e0e8a_row6_col1, #T_e0e8a_row6_col2, #T_e0e8a_row6_col3, #T_e0e8a_row6_col4, #T_e0e8a_row6_col5, #T_e0e8a_row6_col6 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_e0e8a_row5_col1, #T_e0e8a_row5_col2 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# </style>
# <table id="T_e0e8a" style="text-align: center; width: 800px; height: 400px;">
#   <caption><div style="text-align: center; font-size: 18px;">Score Prediction Heatmap<br>Burnley vs Nott'ham Forest</div></caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e0e8a_level0_col0" class="col_heading level0 col0" >0</th>
#       <th id="T_e0e8a_level0_col1" class="col_heading level0 col1" >1</th>
#       <th id="T_e0e8a_level0_col2" class="col_heading level0 col2" >2</th>
#       <th id="T_e0e8a_level0_col3" class="col_heading level0 col3" >3</th>
#       <th id="T_e0e8a_level0_col4" class="col_heading level0 col4" >4</th>
#       <th id="T_e0e8a_level0_col5" class="col_heading level0 col5" >5</th>
#       <th id="T_e0e8a_level0_col6" class="col_heading level0 col6" >6</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e0e8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e0e8a_row0_col0" class="data row0 col0" >5.8%</td>
#       <td id="T_e0e8a_row0_col1" class="data row0 col1" >10.3%</td>
#       <td id="T_e0e8a_row0_col2" class="data row0 col2" >9.1%</td>
#       <td id="T_e0e8a_row0_col3" class="data row0 col3" >5.3%</td>
#       <td id="T_e0e8a_row0_col4" class="data row0 col4" >2.3%</td>
#       <td id="T_e0e8a_row0_col5" class="data row0 col5" >0.8%</td>
#       <td id="T_e0e8a_row0_col6" class="data row0 col6" >0.2%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e0e8a_row1_col0" class="data row1 col0" >6.3%</td>
#       <td id="T_e0e8a_row1_col1" class="data row1 col1" >11.1%</td>
#       <td id="T_e0e8a_row1_col2" class="data row1 col2" >9.8%</td>
#       <td id="T_e0e8a_row1_col3" class="data row1 col3" >5.7%</td>
#       <td id="T_e0e8a_row1_col4" class="data row1 col4" >2.5%</td>
#       <td id="T_e0e8a_row1_col5" class="data row1 col5" >0.9%</td>
#       <td id="T_e0e8a_row1_col6" class="data row1 col6" >0.3%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e0e8a_row2_col0" class="data row2 col0" >3.4%</td>
#       <td id="T_e0e8a_row2_col1" class="data row2 col1" >6.0%</td>
#       <td id="T_e0e8a_row2_col2" class="data row2 col2" >5.3%</td>
#       <td id="T_e0e8a_row2_col3" class="data row2 col3" >3.1%</td>
#       <td id="T_e0e8a_row2_col4" class="data row2 col4" >1.4%</td>
#       <td id="T_e0e8a_row2_col5" class="data row2 col5" >0.5%</td>
#       <td id="T_e0e8a_row2_col6" class="data row2 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e0e8a_row3_col0" class="data row3 col0" >1.2%</td>
#       <td id="T_e0e8a_row3_col1" class="data row3 col1" >2.2%</td>
#       <td id="T_e0e8a_row3_col2" class="data row3 col2" >1.9%</td>
#       <td id="T_e0e8a_row3_col3" class="data row3 col3" >1.1%</td>
#       <td id="T_e0e8a_row3_col4" class="data row3 col4" >0.5%</td>
#       <td id="T_e0e8a_row3_col5" class="data row3 col5" >0.2%</td>
#       <td id="T_e0e8a_row3_col6" class="data row3 col6" >0.1%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e0e8a_row4_col0" class="data row4 col0" >0.3%</td>
#       <td id="T_e0e8a_row4_col1" class="data row4 col1" >0.6%</td>
#       <td id="T_e0e8a_row4_col2" class="data row4 col2" >0.5%</td>
#       <td id="T_e0e8a_row4_col3" class="data row4 col3" >0.3%</td>
#       <td id="T_e0e8a_row4_col4" class="data row4 col4" >0.1%</td>
#       <td id="T_e0e8a_row4_col5" class="data row4 col5" >0.0%</td>
#       <td id="T_e0e8a_row4_col6" class="data row4 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e0e8a_row5_col0" class="data row5 col0" >0.1%</td>
#       <td id="T_e0e8a_row5_col1" class="data row5 col1" >0.1%</td>
#       <td id="T_e0e8a_row5_col2" class="data row5 col2" >0.1%</td>
#       <td id="T_e0e8a_row5_col3" class="data row5 col3" >0.1%</td>
#       <td id="T_e0e8a_row5_col4" class="data row5 col4" >0.0%</td>
#       <td id="T_e0e8a_row5_col5" class="data row5 col5" >0.0%</td>
#       <td id="T_e0e8a_row5_col6" class="data row5 col6" >0.0%</td>
#     </tr>
#     <tr>
#       <th id="T_e0e8a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e0e8a_row6_col0" class="data row6 col0" >0.0%</td>
#       <td id="T_e0e8a_row6_col1" class="data row6 col1" >0.0%</td>
#       <td id="T_e0e8a_row6_col2" class="data row6 col2" >0.0%</td>
#       <td id="T_e0e8a_row6_col3" class="data row6 col3" >0.0%</td>
#       <td id="T_e0e8a_row6_col4" class="data row6 col4" >0.0%</td>
#       <td id="T_e0e8a_row6_col5" class="data row6 col5" >0.0%</td>
#       <td id="T_e0e8a_row6_col6" class="data row6 col6" >0.0%</td>
#     </tr>
#   </tbody>
# </table>
# Win Probabilities for Burnley vs Nott'ham Forest:
# Home Win Probability: 0.23
# Away Win Probability: 0.53
# Draw Probability: 0.23
#
# Raw Prices:
# Home Price : 4.32
# Draw Price : 4.26
# Away Price : 1.88
# ----------------------------------------

# %%
#Calculating win prob & supremacy

def calculate_win_probability(man_city_rating, liverpool_rating):
    formula = -(man_city_rating - liverpool_rating) / 400
    win_probability = 1 / (1 + 10**formula)
    return win_probability

def calculate_supremacy(man_city_rating, liverpool_rating):
    supremacy = (man_city_rating - liverpool_rating) * 0.462476 / abs(man_city_rating - liverpool_rating)
    return supremacy

# SPI ratings
man_city_rating = 2047
liverpool_rating = 1957

# Calculate and print win probability and supremacy
win_probability = calculate_win_probability(man_city_rating, liverpool_rating)
supremacy = calculate_supremacy(man_city_rating, liverpool_rating)

price = 1 / win_probability  # Calculate Price

print(f"Win Probability for Manchester City: {win_probability:.2f}")
print(f"Supremacy for Manchester City: {supremacy:.2f}")
print(f"Price for Manchester City: {price:.2f}")
# Out:
# Win Probability for Manchester City: 0.63
# Supremacy for Manchester City: 0.46
# Price for Manchester City: 1.60

# %%
Win probabilities
Home win probability = []
Draw Probability = []
Away win probability = []

Prices
Home price = []
Draw Price = []
Away Price = []

Supremacy = []

Results
Home Goals = []
Away Goals = []

XG
Home Team XG = []
Away Team XG = []

# %%
import numpy as np

# Number of dice rolls
num_rolls = 10000

# Simulate rolling two dice
dice_rolls = np.random.randint(1, 7, size=(num_rolls, 2))

# Calculate the sum of each pair of dice
dice_sums = np.sum(dice_rolls, axis=1)

# Count occurrences of each sum
sum_counts = np.bincount(dice_sums, minlength=13)[2:]

# Calculate the percentage of each sum
sum_percentages = (sum_counts / num_rolls) * 100

# Print the count and percentage of each sum
for number, (count, percentage) in enumerate(zip(sum_counts, sum_percentages), start=2):
    print(f'Sum {number}: {count} times ({percentage:.2f}%)')
# Out:
# Sum 2: 250 times (2.50%)
# Sum 3: 585 times (5.85%)
# Sum 4: 880 times (8.80%)
# Sum 5: 1106 times (11.06%)
# Sum 6: 1372 times (13.72%)
# Sum 7: 1694 times (16.94%)
# Sum 8: 1356 times (13.56%)
# Sum 9: 1111 times (11.11%)
# Sum 10: 810 times (8.10%)
# Sum 11: 565 times (5.65%)
# Sum 12: 271 times (2.71%)
